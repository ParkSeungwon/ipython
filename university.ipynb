# %%
import pandas as pd

df = pd.read_excel('/home/zezeon/문서/학사/ex2.xlsx', '2018-1')

df2 = df[df[u'국가']=='USA']

df3 = df2[df2.iloc[:,2]=='Exchange']

df3=df3.iloc[:,1:]

df4=df3.drop(df.columns[[2,6,7,8,9,10]],axis=1)

# %%
df4
# Out:
#                                                  대학  선발인원  \
# 1                           Angelo State University     1
# 3                         Arkansas State University     2
# 10                     Black Hills State University     3
# 12  Brooklyn College, \nCity University of New York     2
# 48                        Northern State University    10
# 55                           Stony Brook University     3
# 61                        Tarleton State University     2
# 65                The University of Texas at Dallas     1
# 66                                    Thiel College    10
# 81        University of Missouri-Kansas City (UMKC)     1
# 84                         University of New Mexico     1
# 93             University of Wisconsin, River Falls     2
# 96                        Valdosta State University     2
#
#                     파견가능기간                  학부/대학원  \
# 1   1 semester or \n1 year      Undergraduate Only
# ...

# %%
df4.to_excel('ex.xlsx')

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://zeta:cockcodk0@localhost/site", encoding='utf-8')
conn = engine.connect()
df = pd.read_csv('/home/zeta/다운로드/zomato.csv')

# %%
df.to_sql(name='zomato', con=conn, if_exists='append')
# Out:
# /usr/lib/python2.7/dist-packages/pymysql/cursors.py:165: Warning: (1265, "Data truncated for column 'reviews_list' at row 61")
#   result = self._query(query)
# /usr/lib/python2.7/dist-packages/pymysql/cursors.py:165: Warning: (1265, "Data truncated for column 'reviews_list' at row 36")
#   result = self._query(query)
# /usr/lib/python2.7/dist-packages/pymysql/cursors.py:165: Warning: (1265, "Data truncated for column 'reviews_list' at row 78")
#   result = self._query(query)
# /usr/lib/python2.7/dist-packages/pymysql/cursors.py:165: Warning: (1265, "Data truncated for column 'reviews_list' at row 37")
#   result = self._query(query)
# /usr/lib/python2.7/dist-packages/pymysql/cursors.py:165: Warning: (1265, "Data truncated for column 'reviews_list' at row 60")
#   result = self._query(query)
# /usr/lib/python2.7/dist-packages/pymysql/cursors.py:165: Warning: (1265, "Data truncated for column 'reviews_list' at row 70")
#   result = self._query(query)
# ...

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\n+91 9743772233
# ...

# %%
df2 = df[df[u'listed_in(type)']== 'Buffet']
df2 = df2[df2['listed_in(city)']=='Residency Road']
#df2 = df2[df2['approx_cost(for two people)']< 2000]

# %%
df2.sort_values(by=['rate'], ascending=False)
# Out:
#                                                      url  \
# 47226  https://www.zomato.com/bangalore/rim-naam-the-...
# 47222  https://www.zomato.com/bangalore/olive-bar-and...
# 47228  https://www.zomato.com/bangalore/mainland-chin...
# 47227  https://www.zomato.com/bangalore/oh-calcutta-c...
# 47265  https://www.zomato.com/bangalore/barbeque-nati...
# 47224  https://www.zomato.com/bangalore/jw-kitchen-jw...
# 47238  https://www.zomato.com/bangalore/season-adarsh...
# 47242  https://www.zomato.com/bangalore/cafe-mangii-l...
# 47230  https://www.zomato.com/bangalore/cubbon-pavili...
# 47229  https://www.zomato.com/bangalore/rasovara-lave...
# 47232  https://www.zomato.com/bangalore/le-jardin-the...
# 47223  https://www.zomato.com/bangalore/ebony-mg-road...
# 47264  https://www.zomato.com/bangalore/caraway-kitch...
# 47219  https://www.zomato.com/bangalore/the-market-th...
# 47235  https://www.zomato.com/bangalore/bbqd-global-g...
# ...
