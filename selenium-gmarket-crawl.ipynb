# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup as bs

# %%
drv = webdriver.Firefox()
interval = 0

# %%
def get_url(url):
    global drv, interval
    #time.sleep(5)
    interval += 1
    if interval == 20 : 
        interval = 0
        drv.close()
        drv = webdriver.Firefox()
    print(url)
    drv.get(url)
    return drv.page_source

def gmarket_extract(doc):
    soup = bs(doc, 'lxml')
    title = soup.find('h1', {'class':'itemtit'})
    seller = soup.find('dl', {'class':'exchange_data seller_data'})
    if title is None or seller is None: return ''
    return str(title) + '\n' + str(seller)

def street_extract(doc):
    soup = bs(doc, 'lxml')
    title = soup.find('h1', {'class': 'title'})
    for caption in soup.find_all('caption'):
        if caption.get_text() == '판매자정보 테이블':
            seller = caption.find_parent('table')
    return str(title) + '\n' + str(seller)
                
def extract_link(doc):
    soup = bs(doc, 'lxml')
    return [x.get('href') for x in soup.find_all('a')]

def crawl(url, depth, extract, file):
    if depth == 0: return
    doc = get_url(url)
    if doc == '' or doc is None: return
    result = extract(doc)
    if result is None: return
    print(result)
    f = open(file, 'a')
    f.write(result)
    f.close()
    
    for link in extract_link(doc):
        if link is not None and len(link) > 4 and link[:4] == 'http' and link.find('dealermall') == -1:
            crawl(link, depth - 1, extract, file)

# %%
drv = webdriver.PhantomJS()

# %%
drv.get("https://www.coupang.com")

# %%
soup = bs(drv.page_source, 'lxml')

# %%
print(soup.prettify(formatter='minimal'))
# Out:
# <html lang="ko-KR">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="zaNrGtrOLMjglkziY2IvmL8dOXyCWHGArDHqFazJQVI" name="google-site-verification"/>
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="//cart.coupang.com" rel="dns-prefetch"/>
#   <link href="//assets.coupang.com" rel="dns-prefetch"/>
#   <link href="//assets2.coupang.com" rel="dns-prefetch"/>
#   <link href="//assets.coupangcdn.com" rel="dns-prefetch"/>
#   <link href="//asset1.coupangcdn.com" rel="dns-prefetch"/>
#   <link href="//private.coupang.com" rel="dns-prefetch"/>
#   <link href="//img1a.coupangcdn.com" rel="dns-prefetch"/>
#   <link href="//image1.coupangcdn.com" rel="dns-prefetch"/>
#   <link href="//thumbnail1.coupangcdn.com" rel="dns-prefetch"/>
#   <link href="//www.facebook.com" rel="dns-prefetch"/>
#   <link href="//www.google.com" rel="dns-prefetch"/>
#   <link href="//www.google.co.kr" rel="dns-prefetch"/>
#   <link href="//stats.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="//connect.facebook.net" rel="dns-prefetch"/>
#   <title>
#    쿠팡!
#   </title>
#   <meta content="COUPANG" property="og:title"/>
#   <meta content="//image10.coupangcdn.com/image/mobile/v3/img_fb_like.png" property="og:image"/>
#   <meta content="https://www.coupang.com" property="og:url"/>
#   <meta content="쿠팡은 로켓배송" property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <link href="//image9.coupangcdn.com/image/coupang/favicon/v2/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <!--[if lt IE 9]>
# <script src="/resources/20200917161911/np/js/lib/html5/html5.js" type="text/javascript"></script>
# <![endif]-->
#   <!--[if lte IE 9]>
# <script src="//asset2.coupangcdn.com/cdnjs/json2/20150503/json2.js" type="text/javascript"></script>
# <![endif]-->
#   <link href="/resources/20200917161911/np/css/main_new.min.css" rel="stylesheet" type="text/css"/>
#   <script async="" src="https://connect.facebook.net/signals/config/652323801535981?v=2.9.24&amp;r=stable">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script charset="UTF-8" data-async="false" data-label="home" data-platform="pc" data-section="browser" data-type="today-discovery" id="tti-logger" src="//asset2.coupangcdn.com/customjs/tti-logger/0.6.1/tti-logger.min.js">
#   </script>
#   <script data-auto-send-pageview="false" data-mode="production" data-platform="web" data-service="coupang" data-tti='{"platformType": "browser", "pageName": "home", "async": false, "calcType": "excludeRedirect"}' id="coupang-web-log" src="//asset2.coupangcdn.com/customjs/coupang-web-log/1.3.0/web-log.umd.min.js" type="text/javascript">
#   </script>
#   <style>
#    #coupang-banner span.banner-bg{background:#FFFFFF;border-bottom:1px solid #cac6c3}
#         #coupang-banner span.banner-bg{float:left;width:100%;}
#         #coupang-banner .banner-middle{width:980px;margin:0 auto;}
#         #coupang-banner .banner-middle a{float:left;display: inline-block}
#   </style>
#   <script>
#    bazadebezolkohpepadr="501998476"
#   </script>
#   <script defer="" src="https://www.coupang.com/akam/11/1debe030" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="jquery" src="//asset2.coupangcdn.com/cdnjs/jquery/1.11.1/jquery.min.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="../lib/jquery/plugin/stringify" src="/resources/20200917161911/np/js/modules/../lib/jquery/plugin/stringify.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="../page-controllers/controller-initializer" src="/resources/20200917161911/np/js/modules/../page-controllers/controller-initializer.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/utils/validationUtils" src="/resources/20200917161911/np/js/modules/common/utils/validationUtils.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/essentialData" src="/resources/20200917161911/np/js/modules/common/essentialData.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="handlebars" src="//asset2.coupangcdn.com/cdnjs/handlebars.js/1.3.0/handlebars.min.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="hashchange" src="/resources/20200917161911/np/js/modules/../lib/jquery/jquery.ba-hashchange-1.3-browser-patch.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="../page-controllers/common/controller" src="/resources/20200917161911/np/js/modules/../page-controllers/common/controller.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="../page-controllers/home/controller" src="/resources/20200917161911/np/js/modules/../page-controllers/home/controller.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="couLog" src="//asset2.coupangcdn.com/customjs/cou-log/2.0.0/cou-log.min.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/helper/defaultHelper" src="/resources/20200917161911/np/js/modules/common/helper/defaultHelper.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/abtest/ABTestHelper" src="/resources/20200917161911/np/js/modules/common/abtest/ABTestHelper.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/baseAction" src="/resources/20200917161911/np/js/modules/common/baseAction.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="home/rocketBadge" src="/resources/20200917161911/np/js/modules/home/rocketBadge.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="home/home" src="/resources/20200917161911/np/js/modules/home/home.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/utils/browserChecker" src="/resources/20200917161911/np/js/modules/common/utils/browserChecker.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/adsplatform/adsplatformLogger" src="/resources/20200917161911/np/js/modules/common/adsplatform/adsplatformLogger.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="weblog" src="//asset2.coupangcdn.com/customjs/coupang-web-log/1.3.0/web-log.umd.min.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/utils/cookieUtils" src="/resources/20200917161911/np/js/modules/common/utils/cookieUtils.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/gnbCashWidget" src="/resources/20200917161911/np/js/modules/common/gnbCashWidget.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="moment" src="//asset2.coupangcdn.com/cdnjs/moment.js/2.10.2/moment.min.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/gnbWebLogger" src="/resources/20200917161911/np/js/modules/common/gnbWebLogger.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/template/urlBuilder" src="/resources/20200917161911/np/js/modules/common/template/urlBuilder.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="travel/categoryCheckerTravel" src="/resources/20200917161911/np/js/modules/travel/categoryCheckerTravel.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/template/topBanner" src="/resources/20200917161911/np/js/modules/common/template/topBanner.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/gnbMenuSelector" src="/resources/20200917161911/np/js/modules/common/gnbMenuSelector.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/template/search/KeywordSearch" src="/resources/20200917161911/np/js/modules/common/template/search/KeywordSearch.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/menuSelector" src="/resources/20200917161911/np/js/modules/common/menuSelector.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/template
"8344","option":"B"},{"key":"3738","option":"A"},{"key":"4250","option":"B"},{"key":"4251","option":"B"},{"key":"4252","option":"B"},{"key":"5279","option":"A"},{"key":"3233","option":"B"},{"key":"2723","option":"B"},{"key":"2724","option":"B"},{"key":"3239","option":"B"},{"key":"3240","option":"B"},{"key":"169","option":"B"},{"key":"1706","option":"B"},{"key":"2218","option":"B"},{"key":"3755","option":"A"},{"key":"2731","option":"A"},{"key":"3245","option":"B"},{"key":"2735","option":"A"},{"key":"2736","option":"A"},{"key":"3762","option":"B"},{"key":"2226","option":"A"},{"key":"692","option":"B"},{"key":"1204","option":"A"},{"key":"3253","option":"A"},{"key":"182","option":"B"},{"key":"695","option":"A"},{"key":"1719","option":"B"},{"key":"2743","option":"A"},{"key":"2232","option":"B"},{"key":"3257","option":"A"},{"key":"2748","option": ...
#     "qctoken":"","collectionType":"Home", "webDomain":"", "isTargetOfDeliveryInformation":"false", "freeShippingOverAmount":"", "trCid":"", "trAid":"" }'>
#   <!-- skip navigator -->
#   <nav id="skip-navigation">
#    <h2>
#     스킵 네비게이션
#    </h2>
#    <a href="#login">
#     #로그인 바로가기
#    </a>
#    <a href="#header">
#     #메뉴 바로가기
#    </a>
#    <a href="#gnbAnalytics">
#     #카테고리 바로가기
#    </a>
#    <a href="#contents">
#     #본문 바로가기
#    </a>
#   </nav>
#   <hr/>
#   <div data-use-adzerk="true" id="coupang-banner">
#    <span class="banner-bg">
#     <div class="banner-middle">
#      <a data-adsplatform='{"clickLogUri":"https://mercury.coupang.com/e.gif?r=CgxEMkFZV3p4RWFTS0YSDjE3NS4xOTUuMzAuMTQ3GJm%2B3vLKLiABKiw2aVp2ZmlUY1RLK2szNmJTeTJTQXFPeEZKVlZTb2Y3eHo4cUpWT3VhelhvPTIERkxBVEIXMzIyNjA5MjI3NzQ0NzUwMDc4NDU4NTJQ%2BZbjBFoFY2xpY2t6A1dFQooBBG1hcnOQAeGJC5gBpho%3D&amp;t=1", "impressionLogUri":"https://mercury.coupang.com/e.gif?r=Cgx4SFFRbWVCOFI3aTASDjE3NS4xOTUuMzAuMTQ3GJm%2B3vLKLiABKiw2aVp2ZmlUY1RLK2szNmJTeTJTQXFPeEZKVlZTb2Y3eHo4cUpWT3VhelhvPTIERkxBVEIXMzIyNjA5MjI3NzQ0NzUwMDc4NDU4NTJQ%2BZbjBFoKaW1wcmVzc2lvbnoDV0VCigEEbWFyc5AB4YkLmAGmGg%3D%3D&amp;t=2", "viewImpression":"https://mercury.coupang.com/e.gif?r=CgxaRmtkNDJtekxVaUkSDjE3NS4xOTUuMzAuMTQ3GJm%2B3vLKLiABKiw2aVp2ZmlUY1RLK2szNmJTeTJTQXFPeEZKVlZTb2Y3eHo4cUpWT3VhelhvPTIERkxBVEIXMzIyNjA5MjI3NzQ0NzUwMDc4NDU4NTJQ%2BZbjBFoIaW50b1ZpZXd6A1dFQooBBG1hcnOQAeGJC5gBpho%3D&amp;t=2"}' data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"Topbanner_0"}' data-log-props='{ "id" : "top_banner", "param" : { "bannerLabel":"Topbanner_0"} }' href="https://www.coupang.com/np/campaigns/82">
#       <img alt="" src="https://static.coupangcdn.com/ea/cmg_paperboy/image/1599791038980/0819%28%EC%9B%94%29-C0-Left.jpg"/>
#      </a>
#      <a data-adsplatform='{"clickLogUri":"https://mercury.coupang.com/e.gif?r=CgxSUElyT2xWZmpNaHoSDjE3NS4xOTUuMzAuMTQ3GJm%2B3vLKLiABKiw2aVp2ZmlUY1RLK2szNmJTeTJTQXFPeEZKVlZTb2Y3eHo4cUpWT3VhelhvPTIERkxBVEIXMzIyNjA5MjI3NzQ0NzUwMDc4NDU4NTJQxp7jBFoFY2xpY2t6A1dFQooBBG1hcnOQAeGJC5gBpho%3D&amp;t=1", "impressionLogUri":"https://mercury.coupang.com/e.gif?r=CgxaNWEwQ3FTajc4alMSDjE3NS4xOTUuMzAuMTQ3GJm%2B3vLKLiABKiw2aVp2ZmlUY1RLK2szNmJTeTJTQXFPeEZKVlZTb2Y3eHo4cUpWT3VhelhvPTIERkxBVEIXMzIyNjA5MjI3NzQ0NzUwMDc4NDU4NTJQxp7jBFoKaW1wcmVzc2lvbnoDV0VCigEEbWFyc5AB4YkLmAGmGg%3D%3D&amp;t=2", "viewImpression":"https://mercury.coupang.com/e.gif?r=CgxpYnNlZEpSamRvNEcSDjE3NS4xOTUuMzAuMTQ3GJm%2B3vLKLiABKiw2aVp2ZmlUY1RLK2szNmJTeTJTQXFPeEZKVlZTb2Y3eHo4cUpWT3VhelhvPTIERkxBVEIXMzIyNjA5MjI3NzQ0NzUwMDc4NDU4NTJQxp7jBFoIaW50b1ZpZXd6A1dFQooBBG1hcnOQAeGJC5gBpho%3D&amp;t=2"}' data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"Topbanner_1"}' data-log-props='{ "id" : "top_banner", "param" : { "bannerLabel":"Topbanner_1"} }' href="https://pages.coupang.com/p/16456">
#       <img alt="" src="https://static.coupangcdn.com/ga/cmg_paperboy/image/1600306112424/0921_%E1%84%83%E1%85%A9%E1%86%BC%E1%84%89%E1%85%A5%E1%84%86%E1%85%A2%E1%86%A8%E1%84%89%E1%85%B5%E1%86%B7_C0.jpg"/>
#      </a>
#     </div>
#    </span>
#    <a aria-label="Close" class="close" data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"top_banner_close"}' data-log-props='{ "id" : "top_banner_close" }' role="button">
#     배너 그만 보기
#    </a>
#   </div>
#   <!--[if lte IE 9]>
# <div id="browserSupportWrap">
#     <div class="bs-wrap">
#         <p class="bs-message">고객님의 브라우저에서는 쿠팡이 정상 동작하지 않습니다.<br />
#             인터넷 익스플로러 업데이트, 크롬 또는 파이어폭스 브라우저를 설치하세요.</p>
#         <ul class="bs-browser-download">
#             <li class="ie"><a href="http://windows.microsoft.com/ko-kr/internet-explorer/download-ie" target="_blank">인터넷 익스플로러<br /> <em>업데이트하기</em></a></li>
#             <li class="chrome"><a href="https://www.google.com/chrome/browser/desktop/index.html" target="_blank">크롬<br /> <em>설치하기</em></a></li>
#             <li class="firefox"><a href="https://www.mozilla.org/ko/firefox/new/" target="_blank">파이어폭스<br /> <em>설치하기</em></a></li>
#         </ul>
#     </div>
# </div>
# <![endif]-->
#   <div class="renewal home srp-sync srp-sync-brand" id="container">
#    <div class="renewal-header">
#     <header id="header">
#      <section>
#       <div class="clearFix">
#        <h1>
#         <a data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"coupang_logo"}' data-log-props='{ "id": "coupang_logo" }' href="/" title="Coupang - 내가 잘사는 이유">
#          <img alt="쿠팡로고" height="41" src="//image7.coupangcdn.com/image/coupang/common/logo_coupang_w350.png" width="174"/>
#         </a>
#        </h1>
#        <div class="search-form product-search clearFix">
#         <form action="/np/search" data-actionurl="/np/search" id="headerSearchForm" method="get">
#          <fieldset>
#           <legend>
#            상품검색
#           </legend>
#           <div class="header-searchForm">
#            <div class="select--category">
#             <a class="select--category--button" href="#">
#             </a>
#             <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">
#              전체
#             </a>
#            </div>
#            <select class="search_category_filter" data-name="" id="searchCategories" sb="59479253" style="display: none;">
#             <option value="-1">
#              전체
#             </option>
#             <option data-category-id="186664" value="186764">
#              여성패션
#             </option>
#             <option data-category-id="186969" value="187069">
#              남성패션
#             </option>
#             <option data-category-id="213101" value="213201">
#              베이비패션 (0~3세)
#             </option>
#             <option data-category-id="213414" value="213514">
#              여아패션 (3세 이상)
#             </option>
#             <option data-category-id="213641" value="213741">
#              남아패션 (3세 이상)
#             </option>
#             <option data-category-id="187721" value="187821">
#              스포츠패션
#             </option>
#             <option data-category-id="187265" value="187365">
#              신발
#             </option>
#             <option data-category-id="187377" value="187477">
#              가방/잡화
#             </option>
#             <option data-category-id="176422" value="176522">
#              뷰티
#             </option>
#             <option data-category-id="221834" value="221934">
#              출산/유아동
#             </option>
#             <option data-category-id="194176" value="194276">
#              식품
#             </option>
#             <option data-category-id="185569" value="185669">
#              주방용품
#             </option>
#             <option data-category-id="115573" value="115673">
#              생활용품
#             </option>
#             <option data-category-id="184455" value="184555">
#              홈인테리어
#             </option>
#             <option data-category-id="178155" value="178255">
#              가전디지털
#             </option>
#             <option data-category-id="317678" value="317778">
#              스포츠/레저
#             </option>
#             <option data-category-id="183960" value="184060">
#              자동차용품
#             </option>
#             <option data-category-id="317677" value="317777">
#              도서/음반/DVD
#             </option>
#             <option data-category-id="317679" value="317779">
#              완구/취미
#             </option>
#             <option data-category-id="177195" value="177295">
#              문구/오피스
#             </option>
#             <option data-category-id="115574" value="115674">
#              반려동물용품
#             </option>
#             <option data-category-id="305698" value="305798">
#              헬스/건강식품
#             </option>
#             <option data-category-id="396363" value="396463">
#              국내여행
#             </option>
#             <option data-category-id="396364" value="396464">
#              해외여행
#             </option>
#             <option data-category-id="490208" value="/np/campaigns/6625">
#              2020 추석
#             </option>
#             <option data-category-id="462089" value="/np/campaigns/3884">
#              전문설치
#             </option>
#             <option data-category-id="373623" value="373723">
#              한복
#             </option>
#             <option data-category-id="429673" value="/np/campaigns/2318">
#              공간별 집꾸미기
#             </option>
#             <option data-category-id="414285" value="/np/campaigns/1440">
#              쿠팡 Only
#             </option>
#             <option data-category-id="433684" value="433784">
#              싱글라이프
#             </option>
#             <option data-category-id="427629" value="/np/campaigns/5150">
#              오피스&amp;사업자관
#             </option>
#             <option data-category-id="416030" value="416130">
#              결혼준비
#             </option>
#             <option data-category-id="410173" value="410273">
#              아트/공예
#             </option>
#             <option data-category-id="213100" value="213200">
#              유기농/친환경
#             </option>
#             <option data-category-id="304680" value="304780">
#              여행용품
#             </option>
#             <option data-category-id="397155" value="397255">
#              미세먼지용품
#             </option>
#             <option data-category-id="316068" value="316168">
#              홈카페
#             </option>
#             <option data-category-id="383270" value="383370">
#              실버스토어
#             </option>
#            </select>
#            <div class="select--category" id="sbHolder_59479253">
#             <a class="select--category--button" href="#" id="sbToggle_59479253">
#             </a>
#             <a class="select--category__current" href="#" id="sbSelector_59479253">
#              전체
#             </a>
#             <ul class="select--category--option" id="sbOptions_59479253" style="display: none;">
#              <li>
#               <a href="#-1" rel="-1">
#                전체
#               </a>
#              </li>
#              <li>
#               <a href="#186764" rel="186764">
#                여성패션
#               </a>
#              </li>
#              <li>
#               <a href="#187069" rel="187069">
#                남성패션
#               </a>
#              </li>
#              <li>
#               <a href="#213201" rel="213201">
#                베이비패션 (0~3세)
#               </a>
#              </li>
#              <li>
#               <a href="#213514" rel="213514">
#                여아패션 (3세 이상)
#               </a>
#              </li>
#              <li>
#               <a href="#383370" rel="383370">
#                실버스토어
#               </a>
#              </li>
#             </ul>
#            </div>
#            <input id="searchSelectedCategory" name="component" type="hidden" value=""/>
#            <label for="headerSearchKeyword">
#             <input autocomplete="off" class="coupang-search ad-keyword" data-searchad='{"channel":"", "copy":"찾고 싶은 상품을 검색해보세요!", "linkType":"", "inkContent":"", "newWindow":""}' id="headerSearchKeyword" name="q" title="쿠팡 상품 검색" type="text" value=""/>
#            </label>
#           </div>
#           <input name="channel" type="hidden" value="user"/>
#           <a class="search" href="javascript:;" id="headerSearchBtn" title="검색">
#            검색
#           </a>
#          </fieldset>
#         </form>
#         <div class="popularity-words" id="headerPopupWords">
#         </div>
#         <div class="history-btns">
#          <span class="delete-all-kwdhistory del-button">
#           전체삭제
#          </span>
#          <span class="history-onoff on">
#           최근검색어끄기
#          </span>
#         </div>
#        </div>
#        <ul class="icon-menus">
#         <li class="my-coupang more">
#          <a data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"mycoupang"}' data-log-props='{ "id": "mycoupang" }' href="https://my.coupang.com/purchase/list">
#           <span class="my-coupang-icon">
#           </span>
#           <span class="my-coupang-title">
#            마이쿠팡
#           </span>
#          </a>
#          <p class="my-coupang-menu">
#           <span class="wrapper">
#            <i class="speech-icon">
#            </i>
#            <a data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"mycoupang_1"}' data-log-props='{ "id": "mycoupang_1" }' href="https://my.coupang.com/purchase/list">
#             주문목록
#            </a>
#            <a data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"mycoupang_2"}' data-log-props='{ "id": "mycoupang_2" }' href="https://my.coupang.com/cancelreturn/list">
#             취소/반품
#            </a>
#            <a data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"mycoupang_4"}' data-log-props='{ "id": "mycoupang_4" }' href="//wish-web.coupang.com/wishInitView.pang">
#             찜 리스트
#            </a>
#            <a class="subscription-menu-a" data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"mycoupang_5"}' data-log-props='{ "id": "mycoupang_5" }' href="https://subscribe-order.coupang.com/manage/subs.pang">
#             <span class="subscription-menu-label">
#              정기배송
#             </span>
#             <span class="subscription-menu-warning-icon">
#             </span>
#            </a>
#           </span>
#          </p>
#         </li>
#         <li class="cart more">
#          <a class="clearFix mycart-preview-module" data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"cart"}' data-log-props='{ "id": "cart" }' href="//cart.coupang.com/cartView.pang">
#           <span class="cart-icon">
#           </span>
#           <span class="cart-title">
#            장바구니
#           </span>
#           <em id="headerCartCount">
#            0
#           </em>
#          </a>
#          <div id="mycart-preview">
#           <span class="wrapper">
#            <i class="speech-icon">
#            </i>
#            <ul class="mycart-preview-products">
#            </ul>
#           </span>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <ul class="gnb-menu clearFix">
#        <li class="rocket-delivery">
#         <a class="rocket-delivery " data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"rocketdelivery"}' data-log-props='{ "id":"gnb_menu_item", "param":{"sectionId":"rocketdelivery"} }' href="https://www.coupang.com/np/campaigns/82">
#          로켓배송
#         </a>
#        </li>
#        <li class="rocket-fresh">
#         <a class="rocket-fresh " data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"rocketfresh"}' data-log-props='{ "id":"gnb_menu_item", "param":{"sectionId":"rocketfresh"} }' href="https://www.coupang.com/np/categories/393760">
#          로켓프레시
#         </a>
#         <i class="ic-new">
#         </i>
#        </li>
#        <li class="thanksgiving">
#         <a class="thanksgiving " data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"thanksgiving"}' data-log-props='{ "id":"gnb_menu_item", "param":{"sectionId":"thanksgiving"} }' href="https://pages.coupang.com/p/15666">
#          2020 추석
#         </a>
#         <i class="ic-new">
#         </i>
#        </li>
#        <li class="coupang-global">
#         <a class="coupang-global " data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"coupangglobal"}' data-log-props='{ "id":"gnb_menu_item", "param":{"sectionId":"coupangglobal"} }' href="https://www.coupang.com/np/coupangglobal">
#          로켓직구
#         </a>
#        </li>
#        <li class="">
#         <a class=" " data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"gold_box"}' data-log-props='{ "id":"gnb_menu_item", "param":{"sectionId":"gold_box"} }' href="https://www.coupang.com/np/goldbox">
#          골드박스
#         </a>
#        </li>
#        <li class="subscription">
#         <a class="subscription " data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"subscription"}' data-log-props='{ "id":"gnb_menu_item", "param":{"sectionId":"subscription"} }' href="https://www.coupang.com/np/subscriptiondelivery">
#          정기배송
#         </a>
#        </li>
#        <li class="gnb-coupangbenefit">
#         <a class="gnb-coupangbenefit " data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"coupangbenefit"}' data-log-props='{ "id":"gnb_menu_item", "param":{"sectionId":"coupangbenefit"} }' href="https://www.coupang.com/np/coupangbenefit">
#          이벤트/쿠폰
#         </a>
#        </li>
#        <li class="gnb-exhibition">
#         <a class="gnb-exhibition " data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"exhibition"}' data-log-props='{ "id":"gnb_menu_item", "param":{"sectionId":"exhibition"} }' href="https://www.coupang.com/np/exhibition">
#          기획전
#         </a>
#        </li>
#        <li>
#         <a class="travel" href="https://trip.coupang.com?channel=gnb">
#          여행/티켓
#         </a>
#        </li>
#       </ul>
#      </section>
#      <div class="category-btn category-2depth-active ">
#       <a href="javascript:;">
#        카테고리
#       </a>
#       <div class="category-layer" data-analytics='{"gadisplaypage":"","gadisplaytitle":"쿠팡홈"}' id="gnbAnalytics">
#        <h3 class="none">
#         쇼핑
#        </h3>
#        <ul class="menu shopping-menu-list">
#         <li class="fashion-sundries">
#          <a href="javascript:;" style="cursor: default">
#           패션의류/잡화
#           <i class="select-icon">
#           </i>
#          </a>
#          <div class="depth">
#           <div class="depth-list banner third">
#            <ul>
#             <li class="second-depth-list">
#              <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/186764">
#               여성패션
#               <i class="depth-select-icon">
#               </i>
#              </a>
#              <div class="third-depth-list">
#               <ul>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/186766">
#                  티셔츠
#                 </a>
#                </li>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/186776">
#                  블라우스/셔츠
#                 </a>
#                </li>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/225031">
#                  원피스/세트류
#                 </a>
#                </li>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/186803">
#                  바지/레깅스
#                 </a>
#                </li>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/384822">
#                  스커트/치마
#                 </a>
#                </li>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/186793">
#                  니트류/조끼
#                 </a>
#                </li>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/186771">
#                  맨투맨/후드집업
#                 </a>
#                </li>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/186818">
#                  아우터
#                 </a>
#                </li>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/186827">
#                  패션운동복
#                 </a>
#                </li>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/186836">
#                  비키니/비치웨어
#                 </a>
#                </li>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/186910">
#                  속옷/잠옷
#                 </a>
#                </li>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/186975">
#                  임부복
#                 </a>
#                </li>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"womanclothe"} }' href="/np/categories/402841">
#                  한복/수의
#                 </a>
#                </li>
#                <li class="more-category">
#                 <a href="/np/categories/186764">
#                  더보기
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#             <li class="second-depth-list">
#              <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"manclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"manclothe"} }' href="/np/categories/187069">
#               남성패션
#               <i class="depth-select-icon">
#               </i>
#              </a>
#              <div class="third-depth-list">
#               <ul>
#                <li>
#                 <a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"manclothe"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"manclothe"} }' href="/np/categories/187071">
#                  티셔츠
#                 </a>
#                </li>
#                <li>
# ...
#     + "\", \"content\":\""
#     + escapeExpression((helper = helpers['default'] || (depth0 && depth0['default']),options={hash:{},data:data},helper ? helper.call(depth0, (depth0 && depth0.legacyProductId), options) : helperMissing.call(depth0, "default", (depth0 && depth0.legacyProductId), options)))
#     + "\"}'>\n    ";
#   stack1 = helpers['with'].call(depth0, (depth0 && depth0.imageAndTitleArea), {hash:{},inverse:self.noop,fn:self.program(3, program3, data),data:data});
#   if(stack1 || stack1 === 0) { buffer += stack1; }
#   buffer += "\n\n    ";
#   stack1 = helpers['with'].call(depth0, (depth0 && depth0.priceArea), {hash:{},inverse:self.noop,fn:self.program(10, program10, data),data:data});
#   if(stack1 || stack1 === 0) { buffer += stack1; }
#   buffer += "\n\n    <em class=\"badge\">\n        ";
#   stack1 = helpers['with'].call(depth0, (depth0 && depth0.deadLineArea), {hash:{},inverse:self.noop,fn:self.program(30, program30, data),data:data});
#   if(stack1 || stack1 === 0) { buffer += stack1; }
#   buffer += "\n        ";
#   stack1 = helpers['with'].call(depth0, (depth0 && depth0.badgeArea), {hash:{},inverse:self.noop,fn:self.program(35, program35, data),data:data});
#   if(stack1 || stack1 === 0) { buffer += stack1; }
#   buffer += "\n    </em>\n    ";
#   stack1 = helpers['if'].call(depth0, ((stack1 = (depth0 && depth0.soldoutArea)),stack1 == null || stack1 === false ? stack1 : stack1.soldout), {hash:{},inverse:self.noop,fn:self.program(41, program41, data),data:data});
#   if(stack1 || stack1 === 0) { buffer += stack1; }
#   buffer += "\n\n    </a>\n</li>\n";
#   return buffer;
#   });
#   var templates = Handlebars.templates = Handlebars.templates || {};
#   templates['page/common/plpunit/displayCustomUnit.hbs'] = template;
#   var partials = Handlebars.partials = Handlebars.partials || {};
#   partials['page/common/plpunit/displayCustomUnit.hbs'] = template;
#   return template;
# });
#     define('page/home/unit/recentlyViewedProduct.hbs', ['handlebars'], function(Handlebars) {
#   var template = Handlebars.template(function (Handlebars,depth0,helpers,partials,data) {
#   this.compilerInfo = [4,'>= 1.0.0'];
# helpers = this.merge(helpers, Handlebars.helpers); data = data || {};
#   var buffer = "", stack1, helperMissing=helpers.helperMissing, escapeExpression=this.escapeExpression, self=this, functionType="function";
#
# function program1(depth0,data) {
#
#   var buffer = "", stack1;
#   buffer += "\n    <div class=\"latest-viewed-product\"><h4 class=\"title\">최근 본 상품</h4><a class=\"prev-arrow move prev\"\n                                                                        data-log-props='{ \"id\": \"click_home_product_navigation\", \"param\": {\"eventGroup\": \"LastestViewed\", \"navigationType\": \"arrow_left\"} }'\n                                                                        data-coulog='{\"logCategory\":\"event\", \"logType\":\"click\", \"logLabel\":\"recommendedforyou_left\",\"grp\":\"LastestViewed\"}'></a>\n        <a class=\"next-arrow move next\"\n           data-log-props='{ \"id\": \"click_home_product_navigation\", \"param\": {\"eventGroup\": \"LastestViewed\", \"navigationType\": \"arrow_right\"} }'\n           data-coulog='{\"logCategory\":\"event\", \"logType\":\"click\", \"logLabel\":\"recommendedforyou_right\",\"grp\":\"LastestViewed\"}'></a>\n        <ul class=\"latest-viewed-list\">";
#   stack1 = helpers.each.call(depth0, (depth0 && depth0.recentlyViewed), {hash:{},inverse:self.noop,fn:self.program(2, program2, data),data:data});
#   if(stack1 || stack1 === 0) { buffer += stack1; }
#   buffer += "</ul>\n    </div>";
#   return buffer;
#   }
# function program2(depth0,data) {
#
#   var buffer = "", stack1, helper, options;
#   buffer += "\n            <li class=\""
#     + escapeExpression((helper = helpers['default'] || (depth0 && depth0['default']),options={hash:{},data:data},helper ? helper.call(depth0, (depth0 && depth0.legacyProductId), options) : helperMissing.call(depth0, "default", (depth0 && depth0.legacyProductId), options)))
#     + "\" data-producttype=\""
#     + escapeExpression((helper = helpers['default'] || (depth0 && depth0['default']),options={hash:{},data:data},helper ? helper.call(depth0, ((stack1 = (depth0 && depth0.plpItem)),stack1 == null || stack1 === false ? stack1 : stack1.productType), options) : helperMissing.call(depth0, "default", ((stack1 = (depth0 && depth0.plpItem)),stack1 == null || stack1 === false ? stack1 : stack1.productType), options)))
#     + "\"><p class=\"image\"><img\n              src=\"";
#   stack1 = helpers['if'].call(depth0, ((stack1 = (depth0 && depth0.imageAndTitleArea)),stack1 == null || stack1 === false ? stack1 : stack1.defaultUrl), {hash:{},inverse:self.noop,fn:self.program(3, program3, data),data:data});
#   if(stack1 || stack1 === 0) { buffer += stack1; }
#   buffer += "\" width=\"66\" height=\"66\"\n              alt=\"\"></p>\n                <p class=\"name\">"
#     + escapeExpression(((stack1 = ((stack1 = (depth0 && depth0.plpItem)),stack1 == null || stack1 === false ? stack1 : stack1.title)),typeof stack1 === functionType ? stack1.apply(depth0) : stack1))
#     + "</p>\n                <p class=\"price\">";
#   stack1 = helpers['if'].call(depth0, ((stack1 = (depth0 && depth0.priceTagArea)),stack1 == null || stack1 === false ? stack1 : stack1.title), {hash:{},inverse:self.noop,fn:self.program(5, program5, data),data:data});
#   if(stack1 || stack1 === 0) { buffer += stack1; }
#   buffer += "\n                    <strong>"
#     + escapeExpression((helper = helpers['default'] || (depth0 && depth0['default']),options={hash:{},data:data},helper ? helper.call(depth0, ((stack1 = (depth0 && depth0.priceArea)),stack1 == null || stack1 === false ? stack1 : stack1.price), options) : helperMissing.call(depth0, "default", ((stack1 = (depth0 && depth0.priceArea)),stack1 == null || stack1 === false ? stack1 : stack1.price), options)))
#     + "</strong>원</p>\n                <p class=\"move-detail\"><a class=\"link\" href=\""
#     + escapeExpression((helper = helpers['default'] || (depth0 && depth0['default']),options={hash:{},data:data},helper ? helper.call(depth0, (depth0 && depth0.link), options) : helperMissing.call(depth0, "default", (depth0 && depth0.link), options)))
#     + "\"\n                                          data-log-props='{ \"id\": \"click_home_product\", \"param\": {\"eventGroup\": \"LastestViewed\", \"productId\": \""
#     + escapeExpression((helper = helpers['default'] || (depth0 && depth0['default']),options={hash:{},data:data},helper ? helper.call(depth0, (depth0 && depth0.legacyProductId), options) : helperMissing.call(depth0, "default", (depth0 && depth0.legacyProductId), options)))
#     + "\", \"itemLabel\": \"yourlastviewedproduct_"
#     + escapeExpression(((stack1 = (data == null || data === false ? data : data.index)),typeof stack1 === functionType ? stack1.apply(depth0) : stack1))
#     + "\"} }'\n                                          data-coulog='{\"logCategory\":\"event\", \"logType\":\"click\", \"logLabel\":\"yourlastviewedproduct_"
#     + escapeExpression(((stack1 = (data == null || data === false ? data : data.index)),typeof stack1 === functionType ? stack1.apply(depth0) : stack1))
#     + "\",\"grp\":\"LastestViewed\", \"content\":\""
#     + escapeExpression((helper = helpers['default'] || (depth0 && depth0['default']),options={hash:{},data:data},helper ? helper.call(depth0, (depth0 && depth0.legacyProductId), options) : helperMissing.call(depth0, "default", (depth0 && depth0.legacyProductId), options)))
#     + "\"}'>상세보기 &gt;</a></p></li>";
#   return buffer;
#   }
# function program3(depth0,data) {
#
#   var stack1, helper, options;
#   return escapeExpression((helper = helpers.vCdnThumbnail || (depth0 && depth0.vCdnThumbnail),options={hash:{},data:data},helper ? helper.call(depth0, "66x66ex", ((stack1 = (depth0 && depth0.imageAndTitleArea)),stack1 == null || stack1 === false ? stack1 : stack1.oriDefaultUrl), options) : helperMissing.call(depth0, "vCdnThumbnail", "66x66ex", ((stack1 = (depth0 && depth0.imageAndTitleArea)),stack1 == null || stack1 === false ? stack1 : stack1.oriDefaultUrl), options)));
#   }
#
# function program5(depth0,data) {
#
#   var buffer = "", stack1, helper, options;
#   buffer += " <span class=\"discounted-price\">"
#     + escapeExpression((helper = helpers['default'] || (depth0 && depth0['default']),options={hash:{},data:data},helper ? helper.call(depth0, ((stack1 = (depth0 && depth0.priceTagArea)),stack1 == null || stack1 === false ? stack1 : stack1.title), options) : helperMissing.call(depth0, "default", ((stack1 = (depth0 && depth0.priceTagArea)),stack1 == null || stack1 === false ? stack1 : stack1.title), options)))
#     + "</span> ";
#   return buffer;
#   }
#
#   stack1 = helpers['if'].call(depth0, (depth0 && depth0.recentlyViewed), {hash:{},inverse:self.noop,fn:self.program(1, program1, data),data:data});
#   if(stack1 || stack1 === 0) { buffer += stack1; }
#   buffer += "\n";
#   return buffer;
#   });
#   var templates = Handlebars.templates = Handlebars.templates || {};
#   templates['page/home/unit/recentlyViewedProduct.hbs'] = template;
#   var partials = Handlebars.partials = Handlebars.partials || {};
#   partials['page/home/unit/recentlyViewedProduct.hbs'] = template;
#   return template;
# });
#     define('page/common/alsoViewedProducts.hbs', ['handlebars'], function(Handlebars) {
#   var template = Handlebars.template(function (Handlebars,depth0,helpers,partials,data) {
#   this.compilerInfo = [4,'>= 1.0.0'];
# helpers = this.merge(helpers, Handlebars.helpers); data = data || {};
#   var buffer = "", stack1, helper, functionType="function", escapeExpression=this.escapeExpression;
#
#
#   buffer += "<div id=\"";
#   if (helper = helpers.containerId) { stack1 = helper.call(depth0, {hash:{},data:data}); }
#   else { helper = (depth0 && depth0.containerId); stack1 = typeof helper === functionType ? helper.call(depth0, {hash:{},data:data}) : helper; }
#   buffer += escapeExpression(stack1)
#     + "\" class=\"personalized-widget-container\" data-fodium-widget=\"desktop/widgets/gw/AlsoViewedProducts\" data-fodium-widget-params='{\n         \"feed\": \"";
#   if (helper = helpers.feed) { stack1 = helper.call(depth0, {hash:{},data:data}); }
#   else { helper = (depth0 && depth0.feed); stack1 = typeof helper === functionType ? helper.call(depth0, {hash:{},data:data}) : helper; }
#   buffer += escapeExpression(stack1)
#     + "\",\n         \"minCount\": 5,\n         \"maxCount\": 15\n     }'></div>\n";
#   return buffer;
#   });
#   var templates = Handlebars.templates = Handlebars.templates || {};
#   templates['page/common/alsoViewedProducts.hbs'] = template;
#   var partials = Handlebars.partials = Handlebars.partials || {};
#   partials['page/common/alsoViewedProducts.hbs'] = template;
#   return template;
# });
#     define('page/common/infinityCarousel.hbs', ['handlebars'], function(Handlebars) {
#   var template = Handlebars.template(function (Handlebars,depth0,helpers,partials,data) {
#   this.compilerInfo = [4,'>= 1.0.0'];
# helpers = this.merge(helpers, Handlebars.helpers); data = data || {};
#   var buffer = "", stack1, helper, functionType="function", escapeExpression=this.escapeExpression;
#
#
#   buffer += "<div id=\"";
#   if (helper = helpers.containerId) { stack1 = helper.call(depth0, {hash:{},data:data}); }
#   else { helper = (depth0 && depth0.containerId); stack1 = typeof helper === functionType ? helper.call(depth0, {hash:{},data:data}) : helper; }
#   buffer += escapeExpression(stack1)
#     + "\" class=\"personalized-widget-container\" data-fodium-widget=\"desktop/widgets/gw/InfinityCarousel\" data-fodium-widget-params='{\n         \"feed\": \"";
#   if (helper = helpers.feed) { stack1 = helper.call(depth0, {hash:{},data:data}); }
#   else { helper = (depth0 && depth0.feed); stack1 = typeof helper === functionType ? helper.call(depth0, {hash:{},data:data}) : helper; }
#   buffer += escapeExpression(stack1)
#     + "\",\n         \"minCount\": 5,\n         \"maxCount\": 15\n     }'></div>\n";
#   return buffer;
#   });
#   var templates = Handlebars.templates = Handlebars.templates || {};
#   templates['page/common/infinityCarousel.hbs'] = template;
#   var partials = Handlebars.partials = Handlebars.partials || {};
#   partials['page/common/infinityCarousel.hbs'] = template;
#   return template;
# });
#
#
#
#
#
#     var coupangWebRequire = require.config({
#         baseUrl: '/resources/20200917161911/np/js/modules',
#         context : 'coupangWeb',
# 	    waitSeconds: 7000,
#         paths: {
#             jquery: '//asset2.coupangcdn.com/cdnjs/jquery/1.11.1/jquery.min',
#             hashchange: '../lib/jquery/jquery.ba-hashchange-1.3-browser-patch',
#             handlebars: '//asset2.coupangcdn.com/cdnjs/handlebars.js/1.3.0/handlebars.min',
#             text: '//asset2.coupangcdn.com/cdnjs/require-text/2.0.12/text.min',
#             moment: '//asset2.coupangcdn.com/cdnjs/moment.js/2.10.2/moment.min',
#             momentLocale: '//asset2.coupangcdn.com/cdnjs/moment.js/2.10.2/locales.min',
#             lodash: '//asset2.coupangcdn.com/cdnjs/lodash.js/3.10.1/lodash.min',
#             template: '/resources/20200917161911/np/html/template',
# 			facebook: '//connect.facebook.net/ko_KR/sdk',
#             couLog: '//asset2.coupangcdn.com/customjs/cou-log/2.0.0/cou-log.min',
#             speedChecker: '//asset2.coupangcdn.com/customjs/speed-checker/0.7.3/speed-checker.min',
#             ezPlus: '//asset2.coupangcdn.com/customjs/jquery-elevatezoom-plus/1.1.11/jquery.ez-plus.min',
#             fodiumWidgetLoader: '//asset2.coupangcdn.com/customjs/fodium-widget-loader/1.0.1/fodiumWidgetLoader.min',
#             videojs: '//asset2.coupangcdn.com/cdnjs/video.js/5.16.0/video.min',
#             videohls: '//asset2.coupangcdn.com/cdnjs/videojs-contrib-hls/5.1.1/videojs-contrib-hls',
#             weblog: '//asset2.coupangcdn.com/customjs/coupang-web-log/1.3.0/web-log.umd.min',
#             incorrectInfoBundle: 'sdp/incorrectInfoReport/webpack/incorrectInfoBundle'
#         },
#         shim: {
#             handlebars: {
#                 exports: 'Handlebars'
#             },
#             hashchange: {
#             	deps: ['jquery'],
#             	exports: 'Hashchange'
#         	},
# 			facebook : {
# 				exports: 'FB'
# 			},
# 			couLog: {
# 				deps: ['jquery'],
# 				exports: 'couLog'
# 			},
#             speedChecker: {
#                 deps: ['jquery','couLog'],
#                 exports: 'speedChecker'
#             }
#         }
#     });
#
#         coupangWebRequire([
#             'jquery',
#             'handlebars',
#             'hashchange',
#             '../lib/jquery/plugin/stringify',
#             '../page-controllers/controller-initializer']
#         );
#         // couLog loading for WiseLog
#         coupangWebRequire(['couLog']);
#   </script>
#   <!-- Facebook Pixel Code -->
#   <script>
#    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#             document,'script','https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '652323801535981');
#     fbq('track', 'PageView');
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=652323801535981&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <!-- End Facebook Pixel Code -->
#   <script async="true" src="//asset2.coupangcdn.com/customjs/criteo/5.6.1/ld.min.js" type="text/javascript">
#   </script>
#   <noscript>
#    <img src="https://www.coupang.com/akam/11/pixel_1debe030?a=dD0yODY1ZmQ3YjA2YzZjZWFmNTRiMGNhYmQ5NzY1MTg4MzlhNDQzODU0JmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/>
#   </noscript>
#   <iframe height="0" style="display: none;" title="Criteo DIS iframe" width="0">
#   </iframe>
#   <div id="criteo-tags-div" style="display: none;">
#   </div>
#  </body>
# </html>

# %%
crawl('https://www.gmarket.co.kr', 2, gmarket_extract, 'gmarket.txt')
# Out:
# https://www.gmarket.co.kr
#
# http://myg.gmarket.co.kr/
#
# http://diary2.gmarket.co.kr/Favorite/MyFavoriteItems
#
# https://cart.gmarket.co.kr/ko/cart
#
# http://category.gmarket.co.kr/listview/L100000103.aspx
#
# http://category.gmarket.co.kr/listview/L100000104.aspx
#
# http://category.gmarket.co.kr/listview/L100000105.aspx
#
# http://category.gmarket.co.kr/listview/L100000106.aspx
#
# http://category.gmarket.co.kr/listview/L100000107.aspx
#
# http://category.gmarket.co.kr/listview/L100000096.aspx
#
# http://category.gmarket.co.kr/listview/L100000099.aspx
#
# http://category.gmarket.co.kr/listview/L100000043.aspx
#
# http://rpp.gmarket.co.kr/?exhib=40029
#
# http://rpp.gmarket.co.kr/?exhib=41283
#
# http://rpp.gmarket.co.kr/?exhib=30132
#
# http://rpp.gmarket.co.kr/?exhib=41109
#
# http://rpp.gmarket.co.kr/?exhib=38359
#
# http://rpp.gmarket.co.kr/?exhib=39240
#
# http://rpp.gmarket.co.kr/?exhib=41302
#
# http://promotion.gmarket.co.kr/planview/plan.asp?sid=117050
#
# http://www.gmarket.co.kr/challenge/neo_include/login/redirect_gateway.asp?site=G9&redir=http://www.g9.co.kr/Display/LifeStyle/1000003622
#
# http://www.gmarket.co.kr/challenge/neo_include/login/redirect_gateway.asp?site=G9&redir=http://www.g9.co.kr/Display/LifeStyle/2000003629
#
# http://www.gmarket.co.kr/challenge/neo_include/login/redirect_gateway.asp?site=G9&redir=http://www.g9.co.kr/Display/LifeStyle/2000003617
#
# http://rpp.gmarket.co.kr/?exhib=41131&cpcde=2020Augpda26
#
# http://rpp.gmarket.co.kr/?exhib=41111
#
# http://rpp.gmarket.co.kr/?exhib=41119
#
# http://rpp.gmarket.co.kr/?exhib=41121
#
# http://rpp.gmarket.co.kr/?exhib=41120
#
# http://rpp.gmarket.co.kr/?exhib=40044
#
# http://rpp.gmarket.co.kr/?exhib=36785
#
# http://rpp.gmarket.co.kr/?exhib=41122
#
# http://rpp.gmarket.co.kr/?exhib=41261
#
# http://rpp.gmarket.co.kr/?exhib=41130
#
# http://rpp.gmarket.co.kr/?exhib=32856
#
# http://rpp.gmarket.co.kr/?exhib=38311
#
# http://rpp.gmarket.co.kr/?exhib=23416
#
# http://rpp.gmarket.co.kr/?exhib=36043
#
# http://rpp.gmarket.co.kr/?exhib=38352
#
# http://rpp.gmarket.co.kr/?exhib=38361#ad3
#
# http://corners.gmarket.co.kr/smileclub
#
# http://corners.gmarket.co.kr/Bestsellers
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-20b41b1c6f6a> in <module>()
# ----> 1 crawl('https://www.gmarket.co.kr', 2, gmarket_extract, 'gmarket.txt')
#
# <ipython-input-57-360c409aec52> in crawl(url, depth, extract, file)
#      43     for link in extract_link(doc):
#      44         if link is not None and len(link) > 4 and link[:4] == 'http' and link.find('dealermall') == -1:
# ---> 45             crawl(link, depth - 1, extract, file)
#      46
#      47
#
# <ipython-input-57-360c409aec52> in crawl(url, depth, extract, file)
#      32 def crawl(url, depth, extract, file):
#      33     if depth == 0: return
# ---> 34     doc = get_url(url)
#      35     if doc == '' or doc is None: return
#      36     result = extract(doc)
#
# <ipython-input-57-360c409aec52> in get_url(url)
#       8         drv = webdriver.Firefox()
#       9     print(url)
# ---> 10     drv.get(url)
#      11     return drv.page_source
#      12
#
# /usr/lib/python3/dist-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     321         Loads a web page in the current browser session.
#     322         """
# --> 323         self.execute(Command.GET, {'url': url})
#     324
#     325     @property
#
# /usr/lib/python3/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     307
#     308         params = self._wrap_value(params)
# --> 309         response = self.command_executor.execute(driver_command, params)
#     310         if response:
#     311             self.error_handler.check_response(response)
#
# /usr/lib/python3/dist-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     458         path = string.Template(command_info[1]).substitute(params)
#     459         url = '%s%s' % (self._url, path)
# --> 460         return self._request(command_info[0], url, body=data)
#     461
#     462     def _request(self, method, url, body=None):
#
# /usr/lib/python3/dist-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     482             try:
#     483                 self._conn.request(method, parsed_url.path, body, headers)
# --> 484                 resp = self._conn.getresponse()
#     485             except (httplib.HTTPException, socket.error):
#     486                 self._conn.close()
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1354         try:
#    1355             try:
# -> 1356                 response.begin()
#    1357             except ConnectionError:
#    1358                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
doc = get_url('http://item.gmarket.co.kr/Item?goodsCode=1859437894')
# Out:
# http://item.gmarket.co.kr/Item?goodsCode=1859437894

# %%
gmarket_extract(doc)
# Out:
# '<h1 class="itemtit">특집 바다한끼 해물모둠 8팩+6팩 총 14팩 </h1>\n<dl class="exchange_data seller_data">\n<dt>판매자명</dt><dd>(주)공영홈쇼핑</dd>\n<dt>상호/대표자</dt><dd>최창희 </dd>\n<dt>연락처</dt><dd>15667770</dd>\n<dt>응대가능시간</dt><dd>시 ~ 시</dd>\n<dt>E-mail</dt><dd>opencs@publichs.co.kr</dd>\n<dt>FAX</dt><dd>02-6350-8552</dd>\n<dt>사업자 등록번호</dt><dd>105-88-15349</dd>\n<dt>통신판매업 신고</dt><dd>2015-서울마포-1106</dd>\n<dt>영업소재지</dt><dd>서울특별시 마포구 상암산로 34(상암동,디지털큐브)</dd>\n</dl>'

# %%
s = bs(doc,'lxml')

# %%
s.find_all('h1')
# Out:
# [<h1 class="box__title-logo"><a class="link__head" data-montelena-acode="200003381" data-montelena-floating_yn="N" data-montelena-tour_yn="N" href="//www.gmarket.co.kr"><img alt="G마켓" class="image__logo" height="113" src="//pics.gmarket.co.kr/pc/single/kr/common/image__logo.png" width="240"/><span class="sprite__common">G마켓</span></a></h1>,
#  <h1 class="itemtit">특집 바다한끼 해물모둠 8팩+6팩 총 14팩 </h1>]

# %%
title = s.find('h1', {'class':'itemtit'})
seller = s.find('dl', {'class':'exchange_data seller_data'})

# %%
for i in seller: print(i)
# Out:
# <dt>판매자명</dt>
# <dd>(주)공영홈쇼핑</dd>
#
#
# <dt>상호/대표자</dt>
# <dd>최창희 </dd>
#
#
# <dt>연락처</dt>
# <dd>15667770</dd>
#
#
# <dt>응대가능시간</dt>
# <dd>시 ~ 시</dd>
#
#
# <dt>E-mail</dt>
# <dd>opencs@publichs.co.kr</dd>
#
#
# <dt>FAX</dt>
# <dd>02-6350-8552</dd>
#
#
# <dt>사업자 등록번호</dt>
# <dd>105-88-15349</dd>
#
#
# <dt>통신판매업 신고</dt>
# <dd>2015-서울마포-1106</dd>
#
#
# <dt>영업소재지</dt>
# <dd>서울특별시 마포구 상암산로 34(상암동,디지털큐브)</dd>

# %%
str(seller)
# Out:
# '<dl class="exchange_data seller_data">\n<dt>판매자명</dt><dd>(주)공영홈쇼핑</dd>\n<dt>상호/대표자</dt><dd>최창희 </dd>\n<dt>연락처</dt><dd>15667770</dd>\n<dt>응대가능시간</dt><dd>시 ~ 시</dd>\n<dt>E-mail</dt><dd>opencs@publichs.co.kr</dd>\n<dt>FAX</dt><dd>02-6350-8552</dd>\n<dt>사업자 등록번호</dt><dd>105-88-15349</dd>\n<dt>통신판매업 신고</dt><dd>2015-서울마포-1106</dd>\n<dt>영업소재지</dt><dd>서울특별시 마포구 상암산로 34(상암동,디지털큐브)</dd>\n</dl>'
