# %%
import pandas as pd

# %%
df = pd.read_excel('교환학생.xlsx')

# %%
df
# Out:
#                                     2017-2 파견 영어권 선발내용  \
# 0                                                   국가
# 1                                                   미국
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# ...

# %%
df2 = df.iloc[1:25]

# %%
df3 = df2[df2["Unnamed: 2"]==u'2개 학기']

# %%
df3  = df3[df3['Unnamed: 5'] == u'면제']

# %%
writer = pd.ExcelWriter(path='america.xlsx', engine='xlsxwriter')
df3.to_excel(writer)
writer.save()

# %%
df3
# Out:
#    2017-2 파견 영어권 선발내용                                  Unnamed: 1 Unnamed: 2  \
# 5                 NaN  Black Hills State University\n(교환 / 어학+정규)      2개 학기
# 13                NaN                   Northern State University      2개 학기
# 15                NaN                   Tarleton State University      2개 학기
# 16                NaN                               Thiel College      2개 학기
# 20                NaN      University of New mexico\n(교환 / 어학+정규)      2개 학기
# 22                NaN                   Valdosta State University      2개 학기
#
#    Unnamed: 3                                         Unnamed: 4 Unnamed: 5  \
# 5           5           IBT 61 / PBT 500 / IELTS 5.5 / TOEIC 600         면제
# 13         10                                  IBT 61/ IELTS 5.5         면제
# 15          2                                 IBT 80 / IELTS 6.0         면제
# 16          5                                 IBT 62 / IELTS 5.5         면제
# ...
